# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import glob

# %% [markdown]
# print("data.values")
# print(data.values)
# print("data.dims")
# print(data.dims)
# print("data.coords")
# print(data.coords)
# TANCHAU: 519,1199
# phnompenh: 619,1155
# prekkdam: 646,1140
# kampongcham: 687,1228
# kratie: 735,1286
# stungtreng: 866,1277
# chiangsaen: 1746,570

# %%
directory='/Users/likkhian/Desktop/pythonpost'
fileList = glob.glob(directory+"/hydroout_cesm30/*0000.CHRTOUT_GRID2")
print(len(fileList))
tanchau=[]
phnompenh=[]
prekkdam=[]
kampongcham=[]
kratie=[]
stungtreng=[]
pakse=[]
mukdahan=[]
nakhonphanom=[]
chiangkhan=[]
vientiane=[]
chiangsaen=[]
tot=[]

for thing in fileList:
    data = xr.open_dataset(thing)
#     tanchau.append(data['streamflow'][0,519,1199])
#     phnompenh.append(data['streamflow'][0,619,1155].data)
#     prekkdam.append(data['streamflow'][0,646,1140].data)
#     kampongcham.append(data['streamflow'][0,687,1228].data)
#     kratie.append(data['streamflow'][0,735,1286].data)
#     stungtreng.append(data['streamflow'][0,866,1277].data)
#     pakse.append(data['streamflow'][0,1065,1264].data)
#     mukdahan.append(data['streamflow'][0,1251,1130].data)
#     nakhonphanom.append(data['streamflow'][0,1350,1138].data)
#     chiangkhan.append(data['streamflow'][0,1422,742].data)
#     vientiane.append(data['streamflow'][0,1436,861].data)
#     chiangsaen.append(data['streamflow'][0,1746,570].data)
    tanchau.append(data.streamflow[0,519,1199].data)
    phnompenh.append(data.streamflow[0,619,1155].data)
    prekkdam.append(data.streamflow[0,646,1140].data)
    kampongcham.append(data.streamflow[0,687,1228].data)
    kratie.append(data.streamflow[0,735,1286].data)
    stungtreng.append(data.streamflow[0,866,1277].data)
    pakse.append(data.streamflow[0,1065,1264].data)
    mukdahan.append(data.streamflow[0,1251,1130].data)
    nakhonphanom.append(data.streamflow[0,1350,1138].data)
    chiangkhan.append(data.streamflow[0,1422,742].data)
    vientiane.append(data.streamflow[0,1436,861].data)
    chiangsaen.append(data.streamflow[0,1746,570].data)
    tot.append(np.nansum(data.streamflow.data))
    data.close()
# Out:
# 383

# %%
plt.plot(tot)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(tanchau,label="tanchau")
plt.plot(phnompenh,label="phnompenh")
plt.plot(prekkdam,label="prekkdam")
plt.plot(kampongcham,label="kampongcham")
plt.plot(kratie,label="kratie")
plt.plot(stungtreng,label="stungtreng")
plt.plot(pakse,label="pakse")
plt.plot(mukdahan,label="mukdahan")
plt.plot(nakhonphanom,label="nakhonphanom")
plt.plot(chiangkhan,label="chiangkhan")
plt.plot(vientiane,label="vientiane")
plt.plot(chiangsaen,label="chiangsaen")
plt.legend(loc='upper right')
plt.xlabel("days")
plt.ylabel("flowrate m^3/s")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(vientiane,label="vientiane")
plt.plot(mukdahan,label="mukdahan")
plt.legend(loc='upper left')
plt.show()

# %%
print('june mean %f' %np.mean(kratie2[:30]))
print('july mean %f' %np.mean(kratie2[30:61]))
print('august mean %f' %np.mean(kratie2[61:]))
# Out:
# june mean 28886.916374
# july mean 32568.143964
# august mean 39586.262573

# %%
stream=data["streamflow"]
streamsub=stream[0,:,:].data#450:530,1100:1130]
# %matplotlib qt
plt.pcolormesh(streamsub,vmin=1,vmax=100)
plt.colorbar()
plt.show()

# %%
print(stream[0,1746,570].data)
# Out:
# 264.803955078125

# %%
f=open(directory+"/MRC_Data/vientienMRC_Jun08_Aug08.txt")
MRC=[]
for ii in f.readlines():
    MRC.append(float(ii))

# %%
fig, ax1 = plt.subplots()
t=np.arange(1,93,1)
ax1.plot(t,MRC,'b-')
ax1.set_ylabel('height (MRC)',color='b')
ax2 = ax1.twinx()
ax2.plot(t,vientiane[:-1],'r-')
ax2.set_ylabel('volume (WRFhydro)',color='r')
ax2.set_ylim([0,20000])
plt.title('vientiane')
plt.show()

# %%
fileList2 = glob.glob(directory+"/hydroout_run46/*0000.CHRTOUT_GRID1")
print(len(fileList2))
tanchau2=[]
phnompenh2=[]
prekkdam2=[]
kampongcham2=[]
kratie2=[]
stungtreng2=[]
pakse2=[]
mukdahan2=[]
nakhonphanom2=[]
chiangkhan2=[]
vientiane2=[]

for thing in fileList2:
    data = xr.open_dataset(thing)
    tanchau2.append(data['streamflow'][0,519,1199])
    phnompenh2.append(data['streamflow'][0,619,1155].data)
    prekkdam2.append(data['streamflow'][0,646,1140].data)
    kampongcham2.append(data['streamflow'][0,687,1228].data)
    kratie2.append(data['streamflow'][0,735,1286].data)
    stungtreng2.append(data['streamflow'][0,866,1277].data)
    pakse2.append(data['streamflow'][0,1065,1264].data)
    mukdahan2.append(data['streamflow'][0,1251,1130].data)
    nakhonphanom2.append(data['streamflow'][0,1350,1138].data)
    chiangkhan2.append(data['streamflow'][0,1422,742].data)
    vientiane2.append(data['streamflow'][0,1436,861].data)
# Out:
# 93

# %%
fileList3 = glob.glob(directory+"/hydroout_run32/*0000.CHRTOUT_GRID1")
print(len(fileList3))
tanchau3=[]
phnompenh3=[]
prekkdam3=[]
kampongcham3=[]
kratie3=[]
stungtreng3=[]
pakse3=[]
mukdahan3=[]
nakhonphanom3=[]
chiangkhan3=[]
vientiane3=[]

for thing in fileList3:
    data = xr.open_dataset(thing)
    tanchau3.append(data['streamflow'][0,519,1199])
    phnompenh3.append(data['streamflow'][0,619,1155].data)
    prekkdam3.append(data['streamflow'][0,646,1140].data)
    kampongcham3.append(data['streamflow'][0,687,1228].data)
    kratie3.append(data['streamflow'][0,735,1286].data)
    stungtreng3.append(data['streamflow'][0,866,1277].data)
    pakse3.append(data['streamflow'][0,1065,1264].data)
    mukdahan3.append(data['streamflow'][0,1251,1130].data)
    nakhonphanom3.append(data['streamflow'][0,1350,1138].data)
    chiangkhan3.append(data['streamflow'][0,1422,742].data)
    vientiane3.append(data['streamflow'][0,1436,861].data)
# Out:
# 92

# %%
fileList4 = glob.glob(directory+"/hydroout_run26/*0000.CHRTOUT_GRID1")
print(len(fileList4))
tanchau4=[]
phnompenh4=[]
prekkdam4=[]
kampongcham4=[]
kratie4=[]
stungtreng4=[]
pakse4=[]
mukdahan4=[]
nakhonphanom4=[]
chiangkhan4=[]
vientiane4=[]

for thing in fileList4:
    data = xr.open_dataset(thing)
    tanchau4.append(data['streamflow'][0,519,1199])
    phnompenh4.append(data['streamflow'][0,619,1155].data)
    prekkdam4.append(data['streamflow'][0,646,1140].data)
    kampongcham4.append(data['streamflow'][0,687,1228].data)
    kratie4.append(data['streamflow'][0,735,1286].data)
    stungtreng4.append(data['streamflow'][0,866,1277].data)
    pakse4.append(data['streamflow'][0,1065,1264].data)
    mukdahan4.append(data['streamflow'][0,1251,1130].data)
    nakhonphanom4.append(data['streamflow'][0,1350,1138].data)
    chiangkhan4.append(data['streamflow'][0,1422,742].data)
    vientiane4.append(data['streamflow'][0,1436,861].data)
# Out:
# 92

# %%
MRCVientiane=[3410,6920,11000]
MRCMukdahan=[7090,13600,20600]
MRCKratie=[11200,22200,35500]
wrfVientiane=[4790,7326,10138]
wrfMukdahan=[10557,15289,18740]
wrfKratie=[21540,30849,38676]
plt.plot(np.arange(1,4),MRCVientiane,c='b')
plt.plot(np.arange(1,4),wrfVientiane,c='k')

# %%
Diff=[]
for count in range(0,len(fileList)):
    Diff.append(pakse[count]-pakse2[count])
plt.figure(1)
plt.plot(Diff,color='k')

plt.plot(pakse[0:-1],color='g',label='ffbb')
plt.plot(pakse2[0:-1],color='r',label='ff')
# plt.plot(vientiane3,color='b',label='30d spinup 450/500')
# plt.plot(vientiane4,color='y',label='15d spinup 500/500')
plt.legend(loc='lower right')
plt.title('Comparison of spinup times and Groundwater bucket capacity near beginning')

plt.figure(2)
diffPercent=np.array(Diff)/np.array(pakse)
plt.plot(diffPercent)
plt.title('percentage difference')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
Diff=[]
for count in range(0,len(fileList)):
    Diff.append(tanchau[count]-tanchau2[count])
plt.plot(Diff,color='k')

plt.plot(tanchau[0:-1],color='g',label='ffbb')
plt.plot(tanchau2[0:-1],color='r',label='ff')
# plt.plot(vientiane3,color='b',label='30d spinup 450/500')
# plt.plot(vientiane4,color='y',label='15d spinup 500/500')
plt.legend(loc='upper right')
plt.title('Comparison of spinup times and Groundwater bucket capacity near beginning')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from scipy import correlate
lag = np.argmax(correlate(kratie, kratie2))
print(lag)
print(np.mean(kratie),np.mean(kratie2),(np.mean(kratie)-np.mean(kratie2))/(np.mean(kratie)))
# Out:
# 0
# 34787.5311555 35072.445365 -0.00819012445108

# %%
#relating importance of hydropwer
import pandas as pd
db = pd.read_excel('../HydrologySection/SEA_hydropower.xlsx')
db['Hydropower Development Potential'] = db['Hydropower Potential (GW)'] - db['Hydropower Installed, IHA']
db
# Out:
#        Country  Hydropower Potential (GW)  Hydropower Installed (GW)  \
# 0     Cambodia                     10.000                       0.32
# 1     Thailand                     15.155                       3.48
# 2         Laos                     26.500                       0.70
# 3      Vietnam                     35.000                       5.50
# 4      Myanmar                     46.330                       1.54
# 5  Philippines                     13.000                       3.29
# 6     Malaysia                     30.000                       3.91
# 7    Indonesia                     75.000                       3.88
#
#    Hydropower Installed, IHA  Hydropower Development Potential
# 0                      1.267                             8.733
# 1                      4.510                            10.645
# 2                      4.168                            22.332
# 3                     15.211                            19.789
# 4                      3.140                            43.190
# 5                      4.235                             8.765
# 6                      5.472                            24.528
# 7                      5.258                            69.742

# %%
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05+height,
                '%.1f GW' % float(height),
                ha='center', va='bottom')

plt.rcParams["figure.figsize"] = 9,6
n=8
ind=np.arange(n)
p1=plt.bar(ind,db['Hydropower Installed, IHA'],color='b',align='center')
p2=plt.bar(ind,db['Hydropower Development Potential'],bottom=db['Hydropower Installed, IHA'],color='r',align='center')
p3=plt.bar(ind,db['Hydropower Potential (GW)'],color='',align='center')
plt.ylabel('Hydropower Capacity (GW)')
plt.xticks(ind,db['Country'])
plt.title('Hydropower Capacity in Southeast Asia')
plt.legend((p1[0], p2[0]), ('Installed Capacity', 'Potential Capacity'),loc='upper left')
ax=plt.gca()
ax.set_ylim([0,80])
autolabel(p1)
autolabel(p3)

# %%
np.sum(db['Hydropower Potential (GW)'].iloc[:5])
# Out:
# 132.985

# %%
file=('./209402101200.CHRTOUT_GRID2')
tanchau=[]
phnompenh=[]
prekkdam=[]
kampongcham=[]
kratie=[]
stungtreng=[]
pakse=[]
mukdahan=[]
nakhonphanom=[]
chiangkhan=[]
vientiane=[]
chiangsaen=[]


data = xr.open_dataset(file)
tanchau.append(data['streamflow'][0,519,1199])
phnompenh.append(data['streamflow'][0,619,1155].data)
prekkdam.append(data['streamflow'][0,646,1140].data)
kampongcham.append(data['streamflow'][0,687,1228].data)
kratie.append(data['streamflow'][0,735,1286].data)
stungtreng.append(data['streamflow'][0,866,1277].data)
pakse.append(data['streamflow'][0,1065,1264].data)
mukdahan.append(data['streamflow'][0,1251,1130].data)
nakhonphanom.append(data['streamflow'][0,1350,1138].data)
chiangkhan.append(data['streamflow'][0,1422,742].data)
vientiane.append(data['streamflow'][0,1436,861].data)
chiangsaen.append(data['streamflow'][0,1746,570].data)

# %%
# %matplotlib inline
plt.pcolor(data.streamflow[0,:,:])
plt.show()
# Out:
# C:\Users\likkhian\Anaconda3\lib\site-packages\matplotlib\colors.py:496: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
